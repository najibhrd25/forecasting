# %% [markdown]
# # ForecastLab
#
# ---
#
# ## Bike Sharing Demand Forecasting
#
# ---
#
# | Informasi | Detail |
# |-----------|--------|
# | **Project ID** | FL-001 |
# | **Eksperimen** | EXP-011 |
# | **Nama Eksperimen** | XGBoost |
# | **Dataset** | featured_data.csv |
# | **Tujuan Notebook** | Membangun model XGBoost sebagai model main competitor |
# | **Author** | GAKUSEI Najib |
#
# ---

# %% [markdown]
# ## 1. Tujuan Eksperimen
#
# ### Tujuan
# Membangun model XGBoost dengan hyperparameter default untuk dibandingkan dengan model lain.
#
# ### Hipotesis
# XGBoost menghasilkan performa terbaik karena regularisasi bawaan dan efisiensi gradient boosting.

# %% [markdown]
# ---
# ## 2. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import time
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
sns.set_theme(style='whitegrid')
plt.rcParams['figure.dpi'] = 110
print('Library berhasil diimport.')
# Out:
# Library berhasil diimport.

# %% [markdown]
# ---
# ## 3. Load & Prepare Dataset

# %%
INPUT_PATH = '../data/featured_data.csv'
df = pd.read_csv(INPUT_PATH)
df['dteday'] = pd.to_datetime(df['dteday'])
df = df.sort_values(by=['dteday', 'hr']).reset_index(drop=True)

exclude_cols = ['dteday', 'cnt', 'temp_actual', 'atemp_actual']
feature_cols = [c for c in df.columns if c not in exclude_cols]

train = df[df['yr'] == 0].copy()
test  = df[df['yr'] == 1].copy()

X_train = train[feature_cols].copy()
y_train = train['cnt'].copy()
X_test  = test[feature_cols].copy()
y_test  = test['cnt'].copy()

train_valid = X_train.dropna().index
X_train = X_train.loc[train_valid]
y_train = y_train.loc[train_valid]
test_valid = X_test.dropna().index
X_test = X_test.loc[test_valid]
y_test = y_test.loc[test_valid]

print(f'X_train: {X_train.shape}, X_test: {X_test.shape}')
# Out:
# X_train: (8477, 41), X_test: (8734, 41)

# %% [markdown]
# ---
# ## 4. Train XGBoost

# %%
t0 = time.time()
model_xgb = xgb.XGBRegressor(
    n_estimators=200, learning_rate=0.1, max_depth=7,
    subsample=0.8, colsample_bytree=0.8, random_state=42
)
model_xgb.fit(X_train, y_train)
train_time = time.time() - t0

y_pred_train = model_xgb.predict(X_train)
y_pred_test  = model_xgb.predict(X_test)
print(f'XGBoost berhasil dilatih ({train_time:.2f}s)')
# Out:
# XGBoost berhasil dilatih (2.20s)

# %% [markdown]
# ---
# ## 5. Evaluation

# %%
def evaluate(name, y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
    r2 = r2_score(y_true, y_pred)
    return {'Model': name, 'MAE': mae, 'RMSE': rmse, 'MAPE': mape, 'R2': r2}

df_metrics = pd.DataFrame([
    evaluate('XGBoost (Train)', y_train, y_pred_train),
    evaluate('XGBoost (Test)', y_test, y_pred_test)
])
print(df_metrics.to_string(index=False))
# Out:
#           Model       MAE      RMSE      MAPE       R2
# XGBoost (Train)  6.312131  8.579994 16.550960 0.995921
#  XGBoost (Test) 49.465160 86.111993 27.878979 0.830076

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
n_show = 168
axes[0].plot(range(n_show), y_test.values[:n_show], label='Aktual', color='steelblue')
axes[0].plot(range(n_show), y_pred_test[:n_show], label='Prediksi', color='coral', alpha=0.8)
axes[0].set_title('XGBoost: Prediksi vs Aktual (7 Hari)')
axes[0].legend()

residuals = y_test - y_pred_test
axes[1].scatter(y_pred_test, residuals, alpha=0.3, s=5, color='steelblue')
axes[1].axhline(y=0, color='red', linestyle='--')
axes[1].set_title('Residual Plot')
plt.tight_layout()
plt.savefig('../data/xgb_01_prediction.png', bbox_inches='tight', dpi=110)
plt.show()

# %% [markdown]
# ## 6. Feature Importance

# %%
importances = pd.DataFrame({'Feature': feature_cols, 'Importance': model_xgb.feature_importances_})
importances = importances.sort_values('Importance', ascending=False)

fig, ax = plt.subplots(figsize=(10, 6))
top = importances.head(15)
ax.barh(top['Feature'], top['Importance'], color='steelblue', edgecolor='white')
ax.set_title('Top 15 Feature Importance (XGBoost)')
plt.tight_layout()
plt.savefig('../data/xgb_02_importance.png', bbox_inches='tight', dpi=110)
plt.show()
print(importances.head(10).to_string(index=False))
# Out:
#         Feature  Importance
#      is_daytime    0.242316
#       cnt_lag_1    0.238862
#    is_rush_hour    0.153112
#      cnt_lag_24    0.089043
#     cnt_lag_168    0.037796
#          hr_cos    0.033615
#              hr    0.028409
# hr_x_workingday    0.020352
#     weekday_cos    0.015565
#      is_weekend    0.014586

# %% [markdown]
# ## 7. Kesimpulan
#
# **Insight:**
# - XGBoost kompetitif dengan Gradient Boosting.
# - Ready untuk hyperparameter tuning di EXP-012.
#
# **Next: EXP-012 Hyperparameter Tuning**
